# %% [markdown]
# <a href="https://colab.research.google.com/github/Anishauday/SentimentAnalysiswithBERT/blob/main/BertSentimentAnalysisReviews.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1. Install and Import Dependencies

# %%
# !pip3 install torch==1.8.1+cu111 torchvision==0.9.1+cu111 torchaudio==0.8.1 -f https://download.pytorch.org/whl/torch_stable.html
# Out:
# Looking in links: https://download.pytorch.org/whl/torch_stable.html
# ...
#      |█████████████▌                  | 834.1MB 1.3MB/s eta 0:14:16tcmalloc: large alloc 1147494400 bytes == 0x55ccf04f0000 @  0x7f6c0b770615 0x55ccb7642cdc 0x55ccb772252a 0x55ccb7645afd 0x55ccb7736fed 0x55ccb76b9988 0x55ccb76b44ae 0x55ccb76473ea 0x55ccb76b97f0 0x55ccb76b44ae 0x55ccb76473ea 0x55ccb76b632a 0x55ccb7737e36 0x55ccb76b5853 0x55ccb7737e36 0x55ccb76b5853 0x55ccb7737e36 0x55ccb76b5853 0x55ccb7737e36 0x55ccb77ba3e1 0x55ccb771a6a9 0x55ccb7685cc4 0x55ccb7646559 0x55ccb76ba4f8 0x55ccb764730a 0x55ccb76b53b5 0x55ccb76b47ad 0x55ccb76473ea 0x55ccb76b53b5 0x55ccb764730a 0x55ccb76b53b5
# ...

# %%
# !pip install transformers requests beautifulsoup4 pandas numpy
# Out:
# ...
#      |████████████████████████████████| 2.3MB 5.2MB/s
# ...
#      |████████████████████████████████| 3.3MB 38.1MB/s
# ...
#      |████████████████████████████████| 901kB 44.4MB/s
# ...

# %%
from transformers import AutoTokenizer, AutoModelForSequenceClassification
import torch
import requests
from bs4 import BeautifulSoup
import re

# %% [markdown]
# # 2. Instantiate Model

# %%
tokenizer = AutoTokenizer.from_pretrained('nlptown/bert-base-multilingual-uncased-sentiment')

model = AutoModelForSequenceClassification.from_pretrained('nlptown/bert-base-multilingual-uncased-sentiment')

# %% [markdown]
# # 3. Encode and Calculate Sentiment

# %%
tokens = tokenizer.encode(' Food tasted ok. Could have been better', return_tensors='pt')

# %%
tokens
# Out:
# tensor([[  101, 15225, 44960, 10163, 13563,   119, 12296, 10574, 10662, 16197,
#            102]])

# %%
tokenizer.decode(tokens[0])
# Out:
# '[CLS] food tasted ok. could have been better [SEP]'

# %%
result = model(tokens)

# %%
result.logits
# Out:
# tensor([[-1.2290,  1.2029,  2.6168,  0.2869, -2.4319]],
#        grad_fn=<AddmmBackward>)

# %%
int(torch.argmax(result.logits))+1
# Out:
# 3

# %% [markdown]
# # 4. Collect Reviews

# %%
r = requests.get('https://www.yelp.com/biz/shokudou-san-francisco-5')
soup = BeautifulSoup(r.text, 'html.parser')
regex = re.compile('.*comment.*')
results = soup.find_all('p', {'class':regex})
reviews = [result.text for result in results]

# %%
r.text
# Out:
# '<!DOCTYPE HTML>\n\n<!--[if lt IE 7 ]> <html xmlns:fb="http://www.facebook.com/2008/fbml" class="ie6 ie ltie9 ltie8 no-js" lang="en"> <![endif]-->\n<!--[if IE 7 ]>    <html xmlns:fb="http://www.facebook.com/2008/fbml" class="ie7 ie ltie9 ltie8 no-js" lang="en"> <![endif]-->\n<!--[if IE 8 ]>    <html xmlns:fb="http://www.facebook.com/2008/fbml" class="ie8 ie ltie9 no-js" lang="en"> <![endif]-->\n<!--[if IE 9 ]>    <html xmlns:fb="http://www.facebook.com/2008/fbml" class="ie9 ie no-js" lang="en"> <![endif]-->\n<!--[if (gt IE 9)|!(IE)]><!--> <html xmlns:fb="http://www.facebook.com/2008/fbml" class="no-js" lang="en"> <!--<![endif]-->\n    <head>\n        <script nonce="dfcab7c4">\n            (function() {\n                var main = null;\n\n                var main=function(){window.onerror=function(k,a,c,i,f){var j=(document.getElementsByTagName("html")[0].getAttribute("webdriver")==="true"||navigator.userAgent==="selenium");var h=f&&(f.name==="ServerSideRenderingError"||f.name==="CSR
# ...

# %%
reviews
# Out:
# ['Got take out. \xa0Very authentic, delicious food. \xa0High quality, well prepared, fresh. \xa0Hamachi collar was crispy and well cooked and seasoned, beef enoki, all the sushi was lovely (Hirame appetizer + Sumono with scallop). \xa0Chicken wings were perfect and definitely recommend. \xa0So glad this is here in Bernal! \xa0Would say to add a few things to the menu that are kid friendly as this is great food for adults but my younger one would struggle.',
#  'Wow~this place are so amazing! \xa0This is a new Japanese restaurant still under soft opening with indoor dining available. Inside the restaurant was great with the One Pieces wall decorations and great spacing between tables perfect for social distance. Staff is amazing, super super sweet and attentive. Foods I can talk about is very fresh and delicious.definitely would come back !',
# ...

# %%
results
# Out:
# [<p class="comment__373c0__1M-px css-n6i4z7"><span class=" raw__373c0__3rcx7" lang="en">Got take out.  Very authentic, delicious food.  High quality, well prepared, fresh.  Hamachi collar was crispy and well cooked and seasoned, beef enoki, all the sushi was lovely (Hirame appetizer + Sumono with scallop).  Chicken wings were perfect and definitely recommend.  So glad this is here in Bernal!  Would say to add a few things to the menu that are kid friendly as this is great food for adults but my younger one would struggle.</span></p>,
# ...

# %%
results[0].text
# Out:
# 'Got take out. \xa0Very authentic, delicious food. \xa0High quality, well prepared, fresh. \xa0Hamachi collar was crispy and well cooked and seasoned, beef enoki, all the sushi was lovely (Hirame appetizer + Sumono with scallop). \xa0Chicken wings were perfect and definitely recommend. \xa0So glad this is here in Bernal! \xa0Would say to add a few things to the menu that are kid friendly as this is great food for adults but my younger one would struggle.'

# %% [markdown]
# # 5. Load Reviews into DataFrame and Score

# %%
import numpy as np
import pandas as pd

# %%
df = pd.DataFrame(np.array(reviews), columns=['review'])

# %%
df['review'].iloc[0]
# Out:
# 'Got take out. \xa0Very authentic, delicious food. \xa0High quality, well prepared, fresh. \xa0Hamachi collar was crispy and well cooked and seasoned, beef enoki, all the sushi was lovely (Hirame appetizer + Sumono with scallop). \xa0Chicken wings were perfect and definitely recommend. \xa0So glad this is here in Bernal! \xa0Would say to add a few things to the menu that are kid friendly as this is great food for adults but my younger one would struggle.'

# %%
def sentiment_score(review):
    tokens = tokenizer.encode(review, return_tensors='pt')
    result = model(tokens)
    return int(torch.argmax(result.logits))+1

# %%
sentiment_score(df['review'].iloc[1])
# Out:
# 5

# %%
df['sentiment'] = df['review'].apply(lambda x: sentiment_score(x[:512]))

# %%
df
# Out:
#                                               review  sentiment
# 0  Got take out.  Very authentic, delicious food....          5
# 1  Wow~this place are so amazing!  This is a new ...          5
# 2  This is one hell of a good restaurant. Just at...          2
# 3  We walked around Cortland trying to find a pla...          5
# 4  WOW this place is really good. Like really rea...          5
# 5  Fantastic new sushi place in Bernal! The resta...          5
# 6  COVID-19 TAKEOUT Starting the week off right.....          4
# 7  Wow. Just wow. This place just opened up in my...          5
# 8  Excellent. First time here and we will be back...          5
# 9  AMAZING. Everything we had here was awesome an...          5

# %%
df['review'].iloc[3]
# Out:
# 'We walked around Cortland trying to find a place for dinner when we decided to give the new spot on the street a try! Shokudou is a great new Japanese restaurant that serves fresh sushi. Their dishes are all small portions but think of it similar to tapas. The staff was super friendly and very helpful. Here\'s everything we got with pictures:- Kikusui "Chrysanthemum Water" Sake, $23 (300 ml, good for 3 people each to get 2 small glasses): this was a perfect crisp & clean sake that was easy to drink for people who aren\'t used to sake in general. I would definitely recommend to anyone in that same boat.- Miso Soup, $2.50: very good, a little bit too salty for my taste but was a very satisfying way to start the meal.- Tuna Poke, $12: the fish was so fresh and the mixture of cucumbers, seaweed, and the poke sauce was amazing. It\'s a small portion, meant for you to truly enjoy your food. Absolutely loved it.- Side of Rice, $2.50: we just wanted a side of rice to eat with some of the di
# ...
